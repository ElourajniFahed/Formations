# %%
import findspark
findspark.init("/home/ubuntu/databricks/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">ImportError</span>                               Traceback (most recent call last)
# <span class="ansigreen">&lt;command-3783303836777600&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span><span class="ansigreen">import</span> findspark<span class="ansiyellow"></span>
# <span class="ansigreen">      2</span> findspark<span class="ansiyellow">.</span>init<span class="ansiyellow">(</span><span class="ansiblue">&quot;/home/ubuntu/databricks/&quot;</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">ImportError</span>: No module named &apos;findspark&apos;</div>

# %% [markdown]
# ##Creat a Session

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Crime Cleanin").getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##Import Data

# %%
crimes_df=spark.read.csv("/FileStore/tables/crime.csv",inferSchema=True,header=True)
offense_df=spark.read.csv("/FileStore/tables/offense_codes.csv",inferSchema=True,header=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Data exploring

# %%
display(crimes_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>INCIDENT_NUMBER</th><th>OFFENSE_CODE</th><th>OFFENSE_CODE_GROUP</th><th>OFFENSE_DESCRIPTION</th><th>DISTRICT</th><th>REPORTING_AREA</th><th>SHOOTING</th><th>OCCURRED_ON_DATE</th><th>YEAR</th><th>MONTH</th><th>DAY_OF_WEEK</th><th>HOUR</th><th>UCR_PART</th><th>STREET</th><th>Lat</th><th>Long</th><th>Location</th></tr></thead><tbody><tr><td>I182070945</td><td>619</td><td>Larceny</td><td>LARCENY ALL OTHERS</td><td>D14</td><td>808</td><td>null</td><td>2018-09-02T13:00:00.000+0000</td><td>2018</td><td>9</td><td>Sunday</td><td>13</td><td>Part One</td><td>LINCOLN ST</td><td>42.35779134</td><td>-71.13937053</td><td>(42.35779134, -71.13937053)</td></tr><tr><td>I182070943</td><td>1402</td><td>Vandalism</td><td>VANDALISM</td><td>C11</td><td>347</td><td>null</td><td>2018-08-21T00:00:00.000+0000</td><td>2018</td><td>8</td><td>Tuesday</td><td>0</td><td>Part Two</td><td>HECLA ST</td><td>42.30682138</td><td>-71.06030035</td><td>(42.30682138, -71.06030035)</td></tr><tr><td>I182070941</td><td>3410</td><td>Towed</td><td>TOWED MOTOR VEHICLE</td><td>D4</td><td>151</td><td>null</td><td>2018-09-03T19:27:00.000+0000</td><td>2018</td><td>9</td><td>Monday</td><td>19</td><td>Part Three</td><td>CAZENOVE ST</td><td>42.34658879</td><td>-71.07242943</td><td>(42.34658879, -71.07242943)</td></tr><tr><td>I182070940</td><td>3114</td><td>Investigate Property</td><td>INVESTIGATE PROPERTY</td><td>D4</td><td>272</td><td>null</td><td>2018-09-03T21:16:00.000+0000</td><td>2018</td><td>9</td><td>Monday</td><td>21</td><td>Part Three</td><td>NEWCOMB ST</td><td>42.33418175</td><td>-71.07866441</td><td>(42.33418175, -71.07866441)</td></tr><tr><td>I182070938</td><td>3114</td><td>Investigate Property</td><td>INVESTIGATE PROPERTY</td><td>B3</td><td>421</td><td>null</td><td>2018-09-03T21:05:00.000+0000</td><td>2018</td><td>9</td><td>Monday</td><td>21</td><td>Part Three</td><td>DELHI ST</td><td>42.27536542</td><td>-71.09036101</td><td>(42.27536542, -71.09036101)</td></tr><tr><td>I182070936</td><td>3820</td><td>Motor Vehicle Accident Response</td><td>M/V ACCIDENT INVOLVING PEDESTRIAN - INJURY</td><td>C11</td><td>398</td><td>null</td><td>2018-09-03T21:09:00.000+0000</td><td>2018</td><td>9</td><td>Monday</td><td>21</td><td>Part Three</td><td>TALBOT AVE</td><td>42.29019621</td><td>-71.07159012</td><td>(42.29019621, -71.07159012)</td></tr><tr><td>I182070933</td><td>724</td><td>Auto Theft</td><td>AUTO THEFT</td><td>B2</td><td>330</td><td>null</td><td>2018-09-03T21:25:00.000+0000</td><td>2018</td><td>9</td><td>Monday</td><td>21</td><td>Part One</td><td>NORMANDY ST</td><td>42.30607218</td><td>-71.0827326</td><td>(42.30607218, -71.08273260)</td></tr><tr><td>I182070932</td><td>3301</td><td>Verbal Disputes</td><td>VERBAL DISPUTE</td><td>B2</td><td>584</td><td>null</td><td>2018-09-03T20:39:37.000+0000</td><td>2018</td><td>9</td><td>Monday</td><td>20</td><td>Part Three</td><td>LAWN ST</td><td>42.32701648</td><td>-71.10555088</td><td>(42.32701648, -71.10555088)</td></tr><tr><td>I182070931</td><td>301</td><td>Robbery</td><td>ROBBERY - STREET</td><td>C6</td><td>177</td><td>null</td><td>2018-09-03T20:48:00.000+0000</td><td>2018</td><td>9</td><td>Monday</td><td>20</td><td>Part One</td><td>MASSACHUSETTS AVE</td><td>42.33152148</td><td>-71.07085307</td><td>(42.33152148, -71.07085307)</td></tr><tr><td>I182070929</td><td>3301</td><td>Verbal Disputes</td><td>VERBAL DISPUTE</td><td>C11</td><td>364</td><td>null</td><td>2018-09-03T20:38:00.000+0000</td><td>2018</td><td>9</td><td>Monday</td><td>20</td><td>Part Three</td><td>LESLIE ST</td><td>42.29514664</td><td>-71.05860832</td><td>(42.29514664, -71.05860832)</td></tr><tr><td>I182070928</td><td>3301</td><td>Verbal Disputes</td><td>VERBAL DISPUTE</td><td>C6</td><td>913</td><td>null</td><td>2018-09-03T19:55:00.000+0000</td><td>2018</td><td>9</td><td>Monday</td><td>19</td><td>Part Three</td><td>OCEAN VIEW DR</td><td>42.31957856</td><td>-71.0 ...

# %%
crimes_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">5</span><span class="ansired">]: </span>319073</div>

# %%
crimes_df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- INCIDENT_NUMBER: string (nullable = true)
# -- OFFENSE_CODE: integer (nullable = true)
# -- OFFENSE_CODE_GROUP: string (nullable = true)
# -- OFFENSE_DESCRIPTION: string (nullable = true)
# -- DISTRICT: string (nullable = true)
# -- REPORTING_AREA: string (nullable = true)
# -- SHOOTING: string (nullable = true)
# -- OCCURRED_ON_DATE: timestamp (nullable = true)
# -- YEAR: integer (nullable = true)
# -- MONTH: integer (nullable = true)
# -- DAY_OF_WEEK: string (nullable = true)
# -- HOUR: integer (nullable = true)
# -- UCR_PART: string (nullable = true)
# -- STREET: string (nullable = true)
# -- Lat: double (nullable = true)
# -- Long: double (nullable = true)
# -- Location: string (nullable = true)
#
# </div>

# %%
crimes_df.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+---------------+-----------------+------------------+--------------------+--------+------------------+--------+------------------+------------------+-----------+------------------+--------+-----------+-----------------+------------------+--------------------+
# summary|INCIDENT_NUMBER|     OFFENSE_CODE|OFFENSE_CODE_GROUP| OFFENSE_DESCRIPTION|DISTRICT|    REPORTING_AREA|SHOOTING|              YEAR|             MONTH|DAY_OF_WEEK|              HOUR|UCR_PART|     STREET|              Lat|              Long|            Location|
# +-------+---------------+-----------------+------------------+--------------------+--------+------------------+--------+------------------+------------------+-----------+------------------+--------+-----------+-----------------+------------------+--------------------+
#   count|         319073|           319073|            319073|              319073|  317308|            319073|    1019|            319073|            319073|     319073|            319073|  318983|     308202|           299074|            299074|              319073|
#    mean|    1.4205255E8|2317.546956339145|              null|                null|    null| 383.2111316732648|    null|2016.5605864488691| 6.609719405903978|       null|13.118204924891796|    null|       54.0|42.21438105977153|-70.90827235385385|                null|
#  stddev|            NaN|1185.285542941705|              null|                null|    null|242.28693656444872|    null|0.9963437054210654|3.2736908462624292|       null|6.2942052659439405|    null|        0.0|2.159765638948794| 3.493618072460853|                null|
#     min|      142052550|              111|Aggravated Assault|A&amp;B HANDS, FEET, ...|      A1|                  |       Y|              2015|                 1|     Friday|                 0|   Other| ALBANY ST |             -1.0|      -71.17867378|(-1.00000000, -1....|
#     max|     I182070945|             3831|   Warrant Arrests|WEAPON - OTHER - ...|      E5|                99|       Y|              2018|                12|  Wednesday|                23|Part Two|  ZELLER ST|      42.39504158|              -1.0|(42.39504158, -71...|
# +-------+---------------+-----------------+------------------+--------------------+--------+------------------+--------+------------------+------------------+-----------+------------------+--------+-----------+-----------------+------------------+--------------------+
#
# </div>

# %%
display(crimes_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>INCIDENT_NUMBER</th><th>OFFENSE_CODE</th><th>OFFENSE_CODE_GROUP</th><th>OFFENSE_DESCRIPTION</th><th>DISTRICT</th><th>REPORTING_AREA</th><th>SHOOTING</th><th>OCCURRED_ON_DATE</th><th>YEAR</th><th>MONTH</th><th>DAY_OF_WEEK</th><th>HOUR</th><th>UCR_PART</th><th>STREET</th><th>Lat</th><th>Long</th><th>Location</th></tr></thead><tbody><tr><td>I182070945</td><td>619</td><td>Larceny</td><td>LARCENY ALL OTHERS</td><td>D14</td><td>808</td><td>null</td><td>2018-09-02T13:00:00.000+0000</td><td>2018</td><td>9</td><td>Sunday</td><td>13</td><td>Part One</td><td>LINCOLN ST</td><td>42.35779134</td><td>-71.13937053</td><td>(42.35779134, -71.13937053)</td></tr><tr><td>I182070943</td><td>1402</td><td>Vandalism</td><td>VANDALISM</td><td>C11</td><td>347</td><td>null</td><td>2018-08-21T00:00:00.000+0000</td><td>2018</td><td>8</td><td>Tuesday</td><td>0</td><td>Part Two</td><td>HECLA ST</td><td>42.30682138</td><td>-71.06030035</td><td>(42.30682138, -71.06030035)</td></tr><tr

# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>INCIDENT_NUMBER</th><th>OFFENSE_CODE</th><th>OFFENSE_CODE_GROUP</th><th>OFFENSE_DESCRIPTION</th><th>DISTRICT</th><th>REPORTING_AREA</th><th>SHOOTING</th><th>YEAR</th><th>MONTH</th><th>DAY_OF_WEEK</th><th>HOUR</th><th>UCR_PART</th><th>STREET</th><th>Lat</th><th>Long</th><th>Location</th></tr></thead><tbody><tr><td>count</td><td>319073</td><td>319073</td><td>319073</td><td>319073</td><td>317308</td><td>319073</td><td>1019</td><td>319073</td><td>319073</td><td>319073</td><td>319073</td><td>318983</td><td>308202</td><td>299074</td><td>299074</td><td>319073</td></tr><tr><td>mean</td><td>1.4205255E8</td><td>2317.546956339145</td><td>null</td><td>null</td><td>null</td><td>383.2111316732648</td><td>null</td><td>2016.5605864488691</td><td>6.609719405903978</td><td>null</td><td>13.118204924891796</td><td>null</td><td>54.0</td><td>42.21438105977153</td><td>-70.90827235385385</td><td>null</td></tr><tr><td>stddev</td><td>NaN</td><td>1185.285542941705</td><td>null</td><td>null</td><td>null</td><td>242.28693656444872</td><td>null</td><td>0.9963437054210654</td><td>3.2736908462624292</td><td>null</td><td>6.2942052659439405</td><td>null</td><td>0.0</td><td>2.159765638948794</td><td>3.493618072460853</td><td>null</td></tr><tr><td>min</td><td>142052550</td><td>111</td><td>Aggravated Assault</td><td>A&B HANDS, FEET, ETC.  - MED. ATTENTION REQ.</td><td>A1</td><td> </td><td>Y</td><td>2015</td><td>1</td><td>Friday</td><td>0</td><td>Other</td><td> ALBANY ST </td><td>-1.0</td><td>-71.17867378</td><td>(-1.00000000, -1.00000000)</td></tr><tr><td>max</td><td>I182070945</td><td>3831</td><td>Warrant Arrests</td><td>WEAPON - OTHER - OTHER VIOLATION</td><td>E5</td><td>99</td><td>Y</td><td>2018</td><td>12</td><td>Wednesday</td><td>23</td><td>Part Two</td><td>ZELLER ST</td><td>42.39504158</td><td>-1.0</td><td>(42.39504158, -71.01017732)</td></tr></tbody></table></div>

# %% [markdown]
# there is some columns that has a count number different ot othe column

# %%
crimes_df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">10</span><span class="ansired">]: </span>[&apos;INCIDENT_NUMBER&apos;,
#  &apos;OFFENSE_CODE&apos;,
#  &apos;OFFENSE_CODE_GROUP&apos;,
#  &apos;OFFENSE_DESCRIPTION&apos;,
#  &apos;DISTRICT&apos;,
#  &apos;REPORTING_AREA&apos;,
#  &apos;SHOOTING&apos;,
#  &apos;OCCURRED_ON_DATE&apos;,
#  &apos;YEAR&apos;,
#  &apos;MONTH&apos;,
#  &apos;DAY_OF_WEEK&apos;,
#  &apos;HOUR&apos;,
#  &apos;UCR_PART&apos;,
#  &apos;STREET&apos;,
#  &apos;Lat&apos;,
#  &apos;Long&apos;,
#  &apos;Location&apos;]</div>

# %%
crimes_df=crimes_df.na.fill("N",["SHOOTING"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
crimes_df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------------+------------+--------------------+--------------------+--------+--------------+--------+-------------------+----+-----+-----------+----+----------+-----------+-----------+------------+--------------------+
# INCIDENT_NUMBER|OFFENSE_CODE|  OFFENSE_CODE_GROUP| OFFENSE_DESCRIPTION|DISTRICT|REPORTING_AREA|SHOOTING|   OCCURRED_ON_DATE|YEAR|MONTH|DAY_OF_WEEK|HOUR|  UCR_PART|     STREET|        Lat|        Long|            Location|
# +---------------+------------+--------------------+--------------------+--------+--------------+--------+-------------------+----+-----+-----------+----+----------+-----------+-----------+------------+--------------------+
#      I182070945|         619|             Larceny|  LARCENY ALL OTHERS|     D14|           808|       N|2018-09-02 13:00:00|2018|    9|     Sunday|  13|  Part One| LINCOLN ST|42.35779134|-71.13937053|(42.35779134, -71...|
#      I182070943|        1402|           Vandalism|           VANDALISM|     C11|           347|       N|2018-08-21 00:00:00|2018|    8|    Tuesday|   0|  Part Two|   HECLA ST|42.30682138|-71.06030035|(42.30682138, -71...|
#      I182070941|        3410|               Towed| TOWED MOTOR VEHICLE|      D4|           151|       N|2018-09-03 19:27:00|2018|    9|     Monday|  19|Part Three|CAZENOVE ST|42.34658879|-71.07242943|(42.34658879, -71...|
#      I182070940|        3114|Investigate Property|INVESTIGATE PROPERTY|      D4|           272|       N|2018-09-03 21:16:00|2018|    9|     Monday|  21|Part Three| NEWCOMB ST|42.33418175|-71.07866441|(42.33418175, -71...|
#      I182070938|        3114|Investigate Property|INVESTIGATE PROPERTY|      B3|           421|       N|2018-09-03 21:05:00|2018|    9|     Monday|  21|Part Three|   DELHI ST|42.27536542|-71.09036101|(42.27536542, -71...|
# +---------------+------------+--------------------+--------------------+--------+--------------+--------+-------------------+----+-----+-----------+----+----------+-----------+-----------+------------+--------------------+
# only showing top 5 rows
#
# </div>

# %%
crimes_df=crimes_df.drop("INCIDENT_NUMBER") #Eliminate the Incident Number because it has no effect on our data
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Devise the data into multiple columsn 
from pyspark.sql.functions import year,month,dayofmonth ,minute , second
crimes_df=crimes_df.withColumn("DAY_OF_MONTH",dayofmonth(crimes_df["OCCURRED_ON_DATE"]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
crimes_df.show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+------------------+-------------------+--------+--------------+--------+-------------------+----+-----+-----------+----+--------+----------+-----------+------------+--------------------+------------+
# OFFENSE_CODE|OFFENSE_CODE_GROUP|OFFENSE_DESCRIPTION|DISTRICT|REPORTING_AREA|SHOOTING|   OCCURRED_ON_DATE|YEAR|MONTH|DAY_OF_WEEK|HOUR|UCR_PART|    STREET|        Lat|        Long|            Location|DAY_OF_MONTH|
# +------------+------------------+-------------------+--------+--------------+--------+-------------------+----+-----+-----------+----+--------+----------+-----------+------------+--------------------+------------+
#          619|           Larceny| LARCENY ALL OTHERS|     D14|           808|       N|2018-09-02 13:00:00|2018|    9|     Sunday|  13|Part One|LINCOLN ST|42.35779134|-71.13937053|(42.35779134, -71...|           2|
#         1402|         Vandalism|          VANDALISM|     C11|           347|       N|2018-08-21 00:00:00|2018|    8|    Tuesday|   0|Part Two|  HECLA ST|42.30682138|-71.06030035|(42.30682138, -71...|          21|
# +------------+------------------+-------------------+--------+--------------+--------+-------------------+----+-----+-----------+----+--------+----------+-----------+------------+--------------------+------------+
# only showing top 2 rows
#
# </div>

# %%
crimes_df=crimes_df.withColumn("Minute",minute(crimes_df["OCCURRED_ON_DATE"]))
crimes_df=crimes_df.withColumn("Second",second(crimes_df["OCCURRED_ON_DATE"]))
crimes_df.drop("OCCURRED_ON_DATE")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">16</span><span class="ansired">]: </span>DataFrame[OFFENSE_CODE: int, OFFENSE_CODE_GROUP: string, OFFENSE_DESCRIPTION: string, DISTRICT: string, REPORTING_AREA: string, SHOOTING: string, YEAR: int, MONTH: int, DAY_OF_WEEK: string, HOUR: int, UCR_PART: string, STREET: string, Lat: double, Long: double, Location: string, DAY_OF_MONTH: int, Minute: int, Second: int]</div>

# %%
crimes_df.show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+------------------+-------------------+--------+--------------+--------+-------------------+----+-----+-----------+----+--------+----------+-----------+------------+--------------------+------------+------+------+
# OFFENSE_CODE|OFFENSE_CODE_GROUP|OFFENSE_DESCRIPTION|DISTRICT|REPORTING_AREA|SHOOTING|   OCCURRED_ON_DATE|YEAR|MONTH|DAY_OF_WEEK|HOUR|UCR_PART|    STREET|        Lat|        Long|            Location|DAY_OF_MONTH|Minute|Second|
# +------------+------------------+-------------------+--------+--------------+--------+-------------------+----+-----+-----------+----+--------+----------+-----------+------------+--------------------+------------+------+------+
#          619|           Larceny| LARCENY ALL OTHERS|     D14|           808|       N|2018-09-02 13:00:00|2018|    9|     Sunday|  13|Part One|LINCOLN ST|42.35779134|-71.13937053|(42.35779134, -71...|           2|     0|     0|
#         1402|         Vandalism|          VANDALISM|     C11|           347|       N|2018-08-21 00:00:00|2018|    8|    Tuesday|   0|Part Two|  HECLA ST|42.30682138|-71.06030035|(42.30682138, -71...|          21|     0|     0|
# +------------+------------------+-------------------+--------+--------------+--------+-------------------+----+-----+-----------+----+--------+----------+-----------+------------+--------------------+------------+------+------+
# only showing top 2 rows
#
# </div>

# %%
# we do not need the column Location because we have two column for latitude and langtitude 
crimes_df.select("Location").take(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">18</span><span class="ansired">]: </span>[Row(Location=&apos;(42.35779134, -71.13937053)&apos;),
#  Row(Location=&apos;(42.30682138, -71.06030035)&apos;),
#  Row(Location=&apos;(42.34658879, -71.07242943)&apos;)]</div>

# %%
crimes_df=crimes_df.drop("Location")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#verifi if UCR_Part has null value 
crimes_df.createOrReplaceTempView("crimes_df")
spark.sql("select * from crimes_df where UCR_PART is null").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+------------------+-------------------+--------+--------------+--------+-------------------+----+-----+-----------+----+--------+----------------+-----------+------------+------------+------+------+
# OFFENSE_CODE|OFFENSE_CODE_GROUP|OFFENSE_DESCRIPTION|DISTRICT|REPORTING_AREA|SHOOTING|   OCCURRED_ON_DATE|YEAR|MONTH|DAY_OF_WEEK|HOUR|UCR_PART|          STREET|        Lat|        Long|DAY_OF_MONTH|Minute|Second|
#         2010|     HOME INVASION|      HOME INVASION|      C6|           936|       Y|2018-01-01 16:53:00|2018|    1|     Monday|  16|    null|            B ST|  42.339621|-71.05533044|           1|    53|     0|
#         2010|     HOME INVASION|      HOME INVASION|     C11|           352|       N|2017-12-11 17:03:00|2017|   12|     Monday|  17|    null|        LEROY ST|42.30095488|-71.06537601|          11|     3|     0|
#         2010|     HOME INVASION|      HOME INVASION|     E18|           519|       N|2017-12-04 21:50:00|2017|   12|     Monday|  21|    null|      EVERETT ST|42.25746471|-71.12170562|           4|    50|     0|
#         2010|     HOME INVASION|      HOME INVASION|      B3|           465|       N|2017-11-29 11:41:00|2017|   11|  Wednesday|  11|    null|   BLUE HILL AVE|42.28482577|-71.09137369|          29|    41|     0|
#         2010|     HOME INVASION|      HOME INVASION|     C11|           949|       N|2017-11-20 15:35:00|2017|   11|     Monday|  15|    null|      BOWDOIN ST|42.30839354|-71.06473124|          20|    35|     0|
# +------------+------------------+-------------------+--------+--------------+--------+-------------------+----+-----+-----------+----+--------+----------------+-----------+------------+------------+------+------+
# only showing top 20 rows
#
# </div>

# %%
#verifi the parts that we have
crimes_df.createOrReplaceTempView("crimes_df")
spark.sql("select distinct(UCR_PART) from crimes_df").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+
#   UCR_PART|
# +----------+
#       null|
#      Other|
#   Part Two|
# Part Three|
#   Part One|
# +----------+
#
# </div>

# %%
spark.sql("select * from crimes_df where UCR_PART is null").count()
#we have only 90 record ar null we can delet them it will not be a big deal 
#but we can also give them random parts so we do not loose the data of the others columns in the same row
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">22</span><span class="ansired">]: </span>90</div>

# %%
#creat a functio to make null value represent Other parts 
from pyspark.sql.functions import udf
def update_UCR_PART(strin):
  if strin=="Part One":
    return 1
  if strin=="Part Two":
    return 2
  if strin=="Part Three":
    return 3
  else:
    return 4
  
udf_UCR_PART=udf(update_UCR_PART)
crimes_df=crimes_df.withColumn("UCR_PART" , udf_UCR_PART(crimes_df["UCR_PART"]))
crimes_df.createOrReplaceTempView("crimes_df")

spark.sql("select distinct(UCR_PART) from crimes_df order by  UCR_PART asc").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+
# UCR_PART|
# +--------+
#        1|
#        2|
#        3|
#        4|
# +--------+
#
# </div>

# %%
# verify haw many type of UCR_Part do we have 
from pyspark.sql.functions import countDistinct
crimes_df.select(countDistinct("UCR_PART")).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------------+
# count(DISTINCT UCR_PART)|
# +------------------------+
#                        4|
# +------------------------+
#
# </div>

# %%
display(crimes_df.orderBy('UCR_PART',ascending=True))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>OFFENSE_CODE</th><th>OFFENSE_CODE_GROUP</th><th>OFFENSE_DESCRIPTION</th><th>DISTRICT</th><th>REPORTING_AREA</th><th>SHOOTING</th><th>OCCURRED_ON_DATE</th><th>YEAR</th><th>MONTH</th><th>DAY_OF_WEEK</th><th>HOUR</th><th>UCR_PART</th><th>STREET</th><th>Lat</th><th>Long</th><th>DAY_OF_MONTH</th><th>Minute</th><th>Second</th></tr></thead><tbody><tr><td>301</td><td>Robbery</td><td>ROBBERY - STRE
td>19</td><td>0</td><td>0</td></tr><tr><td>617</td><td>Larceny</td><td>LARCENY THEFT FROM BUILDING</td><td>D4</td><td>134</td><td>N</td><td>2015-08-27T17:04:00.000+0000</td><td>2015</td><td>8</td><td>Thursday</td><td>17</td><td>1</td><td>BOYLSTON ST</td><td>42.3503787</td><td>-71.07626098</td><td>27</td><td>4</td><td>0</td></tr><tr><td>520</td><td>Residential Burglary</td><td>BURGLARY - RESIDENTIAL - FORCE</td><td>B2</td><td>267</td><td>N</td><td>2015-08-20T08:18:00.000+0000</td><td>2015</td><td>8</td><td>Thursday</td><td>8</td><td>1</td><td>MOUNT PLEASANT AVE</td><td>42.3263576</td><td>-71.07886301</td><td>20</td><td>18</td><td>0</td></tr><tr><td>617</td><td>Larceny</td><td>LARCENY THEFT FROM BUILDING</td><td>B3</td><td>423</td><td>N</td><td>2015-08-27T16:52:00.000+0000</td><td>2015</td><td>8</td><td>Thursday</td><td>16</td><td>1</td><td>RIDGEVIEW AVE ...

# %%
#the most repetitive offence in the data cet 
crimes_df.groupBy("OFFENSE_CODE_GROUP").count().orderBy("count",ascending=False).show(truncate=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----+
#   OFFENSE_CODE_GROUP|count|
# +--------------------+-----+
# Motor Vehicle Acc...|37132|
#              Larceny|25935|
#   Medical Assistance|23540|
#   Investigate Person|18750|
#                Other|18075|
#       Drug Violation|16548|
#       Simple Assault|15826|
#            Vandalism|15415|
#      Verbal Disputes|13099|
#                Towed|11287|
# Investigate Property|11124|
# Larceny From Moto...|10847|
#        Property Lost| 9751|
#      Warrant Arrests| 8407|
#   Aggravated Assault| 7807|
#           Violations| 6095|
#                Fraud| 5829|
# Residential Burglary| 5606|
# Missing Person Lo...| 4958|
#           Auto Theft| 4851|
# +--------------------+-----+
# only showing top 20 rows
#
# </div>

# %%
#the day where the number of crimes increase 
crimes_df.groupBy("DAY_OF_WEEK").count().orderBy("count",ascending=False).take(1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">38</span><span class="ansired">]: </span>[Row(DAY_OF_WEEK=&apos;Friday&apos;, count=48495)]</div>

# %%
# we have only 4 part so  this columnt of string we kan transform it into column of number where each number represent a Pärt exp Part 1 is eagau to number 1
from pyspark.ml.feature import StringIndexer
#indexer=StringIndexer(inputCol="UCR_PART",outputCol="UCR_PART_NUMBER")
#crimes_df=indexer.fit(crimes_df.orderBy('UCR_PART',ascending=True)).transform(crimes_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
crimes_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+--------------------+--------------------+--------+--------------+--------+-------------------+----+-----+-----------+----+--------+-----------------+-----------+------------+------------+------+------+
# OFFENSE_CODE|  OFFENSE_CODE_GROUP| OFFENSE_DESCRIPTION|DISTRICT|REPORTING_AREA|SHOOTING|   OCCURRED_ON_DATE|YEAR|MONTH|DAY_OF_WEEK|HOUR|UCR_PART|           STREET|        Lat|        Long|DAY_OF_MONTH|Minute|Second|
# +------------+--------------------+--------------------+--------+--------------+--------+-------------------+----+-----+-----------+----+--------+-----------------+-----------+------------+------------+------+------+
#         3301|     Verbal Disputes|      VERBAL DISPUTE|     C11|           341|       N|2018-09-03 18:52:00|2018|    9|     Monday|  18|       3|    STONEHURST ST|42.30526428|-71.06683755|           3|    52|     0|
#         3305|Assembly or Gathe...| DEMONSTRATIONS/RIOT|      D4|           130|       N|2018-09-03 17:00:00|2018|    9|     Monday|  17|       3|   HUNTINGTON AVE|42.34857652|-71.07772012|           3|     0|     0|
#         2647|               Other|THREATS TO DO BOD...|      B2|           901|       N|2018-09-03 19:52:00|2018|    9|     Monday|  19|       2|      HORADAN WAY|42.33371742|-71.09665806|           3|    52|     0|
#          614|Larceny From Moto...|LARCENY THEFT FRO...|      B2|           181|       N|2018-09-02 18:00:00|2018|    9|     Sunday|  18|       1|       SHIRLEY ST| 42.3256949|-71.06816778|           2|     0|     0|
# +------------+--------------------+--------------------+--------+--------------+--------+-------------------+----+-----+-----------+----+--------+-----------------+-----------+------------+------------+------+------+
# only showing top 20 rows
#
# </div>

# %%
from pyspark.sql.functions import dayofweek
crimes_df.withColumn("DAY_OF_WEEK",dayofweek(crimes_df["OCCURRED_ON_DATE"])).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+--------------------+--------------------+--------+--------------+--------+-------------------+----+-----+-----------+----+--------+-----------------+-----------+------------+------------+------+------+
# OFFENSE_CODE|  OFFENSE_CODE_GROUP| OFFENSE_DESCRIPTION|DISTRICT|REPORTING_AREA|SHOOTING|   OCCURRED_ON_DATE|YEAR|MONTH|DAY_OF_WEEK|HOUR|UCR_PART|           STREET|        Lat|        Long|DAY_OF_MONTH|Minute|Second|
# +------------+--------------------+--------------------+--------+--------------+--------+-------------------+----+-----+-----------+----+--------+-----------------+-----------+------------+------------+------+------+
#          619|             Larceny|  LARCENY ALL OTHERS|     D14|           808|       N|2018-09-02 13:00:00|2018|    9|          1|  13|       1|       LINCOLN ST|42.35779134|-71.13937053|           2|     0|     0|
#         1402|           Vandalism|           VANDALISM|     C11|           347|       N|2018-08-21 00:00:00|2018|    8|          3|   0|       2|         HECLA ST|42.30682138|-71.06030035|          21|     0|     0|
#         3410|               Towed| TOWED MOTOR VEHICLE|      D4|           151|       N|2018-09-03 19:27:00|2018|    9|          2|  19|       3|      CAZENOVE ST|42.34658879|-71.07242943|           3|    27|     0|
#         3114|Investigate Property|INVESTIGATE PROPERTY|      D4|           272|       N|2018-09-03 21:16:00|2018|    9|          2|  21|       3|       NEWCOMB ST|42.33418175|-71.07866441|           3|    16|     0|
#         3114|Investigate Property|INVESTIGATE PROPERTY|      B3|           421|       N|2018-09-03 21:05:00|2018|    9|          2|  21|       3|         DELHI ST|42.27536542|-71.09036101|           3|     5|     0|
#         3820|Motor Vehicle Acc...|M/V ACCIDENT INVO...|     C11|           398|       N|2018-09-03 21:09:00|2018|    9|          2|  21|       3|       TALBOT AVE|42.29019621|-71.07159012|           3|     9|     0|
#          724|          Auto Theft|          AUTO THEFT|      B2|           330|       N|2018-09-03 21:25:00|2018|    9|          2|  21|       1|      NORMANDY ST|42.30607218| -71.0827326|           3|    25|     0|
